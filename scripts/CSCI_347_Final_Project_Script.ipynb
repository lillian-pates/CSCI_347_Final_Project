# %% [markdown]
# # CSCI 347 Final Project

# %% [markdown]
# Bailey Binando, Caitlin Hermanson, Lilly Pates

# %%
# %cd ~/Desktop/CSCI347/CSCI_347_Final_Project
# Out:
# /Users/baileybinando/Desktop/CSCI347/CSCI_347_Final_Project

# %%
# load libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.decomposition import KernelPCA
from sklearn.metrics import silhouette_score
import seaborn as sns

# %%
# load data
df = pd.read_csv("data/master_full_rolling_5day_features.csv")
df.head()  # glimpse at structure: each row is a 5-day window
# Out:
#   window_id center_date window_start  window_end  window_n_days  \
# 0   W000001  1975-01-04   1975-01-02  1975-01-06              5
# 1   W000002  1975-01-05   1975-01-03  1975-01-07              5
# 2   W000003  1975-01-06   1975-01-04  1975-01-08              5
# 3   W000004  1975-01-07   1975-01-05  1975-01-09              5
# 4   W000005  1975-01-08   1975-01-06  1975-01-10              5
#
#    is_flood_event  n_flood_days_in_window  days_to_nearest_flood_in_window  \
# 0               0                       0                              NaN
# 1               0                       0                              NaN
# 2               0                       0                              NaN
# 3               0                       0                              NaN
# 4               0                       0                              NaN
#
#    flow_raw_max  flow_raw_mean  ...  storm_wind_mean  RH2M_max  RH2M_mean  \
# 0       50.0305       36.84938  ...              0.0       NaN        NaN
# 1       45.3183       34.26694  ...              0.0       NaN        NaN
# 2       45.3183       37.87166  ...              0.0       NaN        NaN
# 3       45.3183       38.02028  ...              0.0       NaN        NaN
# 4       42.1990       34.75174  ...              0.0       NaN        NaN
#
#    WS2M_max  WS2M_mean  storm_max_wind_kt_max  storm_max_wind_kt_mean  \
# 0       NaN        NaN                      0                     0.0
# 1       NaN        NaN                      0                     0.0
# 2       NaN        NaN                      0                     0.0
# 3       NaN        NaN                      0                     0.0
# 4       NaN        NaN                      0                     0.0
#
#    rp_for_impact  impact_proxy  impact_proxy_log
# 0       3.198489  29791.041222         10.301997
# 1       2.891200  28186.746623         10.246643
# 2       2.891200  28186.746623         10.246643
# 3       2.891200  28186.746623         10.246643
# 4       2.692491  27107.964132         10.207620
#
# [5 rows x 60 columns]

# %% [markdown]
# ## Feature Selection

# %%
# Spearman correlation with impact_proxy to rank feature relevance
# Using Spearman (rank-based) because the relationship may not be linear
num_df = df.select_dtypes(include = [np.number]).copy()

# drop rows with missing values for stable correlations
num_df = num_df.dropna()

# Spearman correlation with impact
corr_to_impact = (
    num_df.corr(method="spearman")["impact_proxy"].sort_values(ascending = False)
)

print(corr_to_impact)
# Out:
# impact_proxy_log                   1.000000
# impact_proxy                       1.000000
# rp_for_impact                      1.000000
# rp_approx_max                      0.999928
# flow_raw_max                       0.979499
# flow_pct_max                       0.979499
# max_exceedance_90                  0.979042
# api_k_0_70_max                     0.964886
# rain_2day_max                      0.936105
# rain_3day_max                      0.919006
# rp_approx_mean                     0.907794
# api_k_0_80_max                     0.907667
# rain_4day_max                      0.879679
# tp_12h_intensity_mm_hr_max         0.868475
# rain_1day_max                      0.863400
# flow_raw_mean                      0.862610
# api_k_0_85_max                     0.854213
# rain_3day_mean                     0.852236
# rain_2day_mean                     0.849658
# tp_12h_intensity_mm_hr_mean        0.844644
# api_k_0_70_mean                    0.832216
# rain_5day_max                      0.826415
# rain_4day_mean                     0.819863
# tp_6h_intensity_mm_hr_max          0.817768
# rain_1day_mean                     0.802325
# tp_6h_intensity_mm_hr_mean         0.795420
# api_k_0_90_max                     0.780979
# rain_5day_mean                     0.769141
# api_k_0_80_mean                    0.748999
# area_above_90                      0.728524
# rain_7day_max                      0.728506
# api_k_0_85_mean                    0.673396
# RH2M_max                           0.663369
# rain_7day_mean                     0.635639
# WS2M_max                           0.612498
# api_k_0_95_max                     0.607842
# api_k_0_90_mean                    0.563288
# WS2M_mean                          0.536816
# flow_pct_mean                      0.531697
# RH2M_mean                          0.464881
# storm_within_500km                 0.461543
# duration_above_90                  0.446252
# storm_within_300km                 0.428611
# rain_14day_max                     0.402600
# api_k_0_95_mean                    0.386764
# n_flood_days_in_window             0.344581
# rain_14day_mean                    0.308642
# days_to_peak_flow                  0.174225
# storm_wind_mean                    0.125895
# storm_max_wind_kt_mean             0.125895
# storm_wind_max                     0.109406
# storm_max_wind_kt_max              0.109406
# days_to_nearest_flood_in_window   -0.366806
# storm_min_distance_km             -0.378048
# window_n_days                           NaN
# is_flood_event                          NaN
# Name: impact_proxy, dtype: float64

# %%
# Variation correlation to each other 
num_df = df.select_dtypes(include=[np.number]).dropna()
corr = num_df.corr(method="spearman")

upper = corr.abs().where(
    np.triu(np.ones(corr.shape), k=1).astype(bool)
)

high_corr = upper.stack().reset_index()
high_corr.columns = ["variable1", "variable2", "corr"]

high_corr = high_corr[high_corr["corr"] > 0.85]

# sort
high_corr = high_corr.sort_values("corr", ascending=False)

print(high_corr.to_string(index=False))
# Out:
#                  variable1                       variable2     corr
#               impact_proxy                impact_proxy_log 1.000000
#               flow_raw_max                    flow_pct_max 1.000000
#            storm_wind_mean          storm_max_wind_kt_mean 1.000000
#             storm_wind_max           storm_max_wind_kt_max 1.000000
#              rp_for_impact                    impact_proxy 1.000000
#              rp_for_impact                impact_proxy_log 1.000000
#              rp_approx_max                    impact_proxy 0.999928
#              rp_approx_max                   rp_for_impact 0.999928
#              rp_approx_max                impact_proxy_log 0.999928
#               flow_pct_max               max_exceedance_90 0.999436
#               flow_raw_max               max_exceedance_90 0.999436
#             rain_4day_mean                 api_k_0_70_mean 0.987587
#            api_k_0_80_mean                 api_k_0_85_mean 0.986692
#             api_k_0_80_max                  api_k_0_85_max 0.986344
#              flow_raw_mean                  rp_approx_mean 0.982340
#              flow_raw_mean                 api_k_0_70_mean 0.981335
#               flow_pct_max                  api_k_0_70_max 0.980697
#               flow_raw_max                  api_k_0_70_max 0.980697
#          max_exceedance_90                  api_k_0_70_max 0.980315
#               flow_raw_max                   rp_approx_max 0.979570
#               flow_pct_max                   rp_approx_max 0.979570
#               flow_raw_max                impact_proxy_log 0.979499
#               flow_raw_max                    impact_proxy 0.979499
#               flow_raw_max                   rp_for_impact 0.979499
#               flow_pct_max                impact_proxy_log 0.979499
#               flow_pct_max                    impact_proxy 0.979499
#               flow_pct_max                   rp_for_impact 0.979499
#          max_exceedance_90                impact_proxy_log 0.979042
#          max_exceedance_90                    impact_proxy 0.979042
#          max_exceedance_90                   rp_for_impact 0.979042
#             api_k_0_85_max                  api_k_0_90_max 0.979005
#          max_exceedance_90                   rp_approx_max 0.978971
#             rain_4day_mean                  rain_5day_mean 0.977713
#            api_k_0_85_mean                 api_k_0_90_mean 0.976460
# tp_6h_intensity_mm_hr_mean     tp_12h_intensity_mm_hr_mean 0.975680
#             rain_5day_mean                 api_k_0_80_mean 0.974531
#            api_k_0_70_mean                 api_k_0_80_mean 0.973632
#             rain_5day_mean                 api_k_0_70_mean 0.971876
#             rain_3day_mean                  rain_4day_mean 0.971796
#             api_k_0_70_max                  api_k_0_80_max 0.970645
#             rain_3day_mean                 api_k_0_70_mean 0.964899
#             api_k_0_70_max                   rp_for_impact 0.964886
#             api_k_0_70_max                    impact_proxy 0.964886
#             api_k_0_70_max                impact_proxy_log 0.964886
#              rp_approx_max                  api_k_0_70_max 0.964838
#              rain_4day_max                   rain_5day_max 0.964540
#             rp_approx_mean                 api_k_0_70_mean 0.964119
#  tp_6h_intensity_mm_hr_max      tp_12h_intensity_mm_hr_max 0.962461
#             rain_2day_mean                  rain_3day_mean 0.961235
#              flow_raw_mean                  rain_4day_mean 0.960621
#              rain_3day_max                  api_k_0_70_max 0.959600
#             rain_7day_mean                 api_k_0_85_mean 0.957184
#              flow_raw_mean                  rain_3day_mean 0.956784
#             rain_1day_mean     tp_12h_intensity_mm_hr_mean 0.956199
#              rain_5day_max                  api_k_0_80_max 0.956129
#              area_above_90                 api_k_0_80_mean 0.954636
#               flow_raw_max                   rain_2day_max 0.954168
#               flow_pct_max                   rain_2day_max 0.954168
#          max_exceedance_90                   rain_2day_max 0.953872
#             rain_1day_mean                  rain_2day_mean 0.953799
#             rp_approx_mean                  rain_3day_mean 0.952190
#             rain_4day_mean                 api_k_0_80_mean 0.952108
#              rain_5day_max                  api_k_0_85_max 0.952037
#              rain_4day_max                  api_k_0_70_max 0.951537
#              flow_raw_mean                 api_k_0_80_mean 0.951035
#              rain_4day_max                  api_k_0_80_max 0.951008
#             rain_1day_mean      tp_6h_intensity_mm_hr_mean 0.949718
#             rain_2day_mean     tp_12h_intensity_mm_hr_mean 0.948497
#              rain_3day_max                   rain_4day_max 0.947863
#             rain_7day_mean                 api_k_0_80_mean 0.947708
#             rain_5day_mean                 api_k_0_85_mean 0.944763
#              area_above_90                 api_k_0_85_mean 0.944116
#             rp_approx_mean                  rain_4day_mean 0.942727
#              rain_7day_max                  api_k_0_85_max 0.942645
#              rain_2day_max      tp_12h_intensity_mm_hr_max 0.941737
#              rain_7day_max                  api_k_0_90_max 0.941516
#             api_k_0_80_max                  api_k_0_90_max 0.941249
#             rain_5day_mean                  rain_7day_mean 0.940052
#              rain_5day_max                   rain_7day_max 0.937890
#              area_above_90                 api_k_0_70_mean 0.937714
#              rain_2day_max                impact_proxy_log 0.936105
#              rain_2day_max                    impact_proxy 0.936105
#              rain_2day_max                   rp_for_impact 0.936105
#              rp_approx_max                   rain_2day_max 0.936019
#              rain_1day_max      tp_12h_intensity_mm_hr_max 0.934422
#               flow_raw_max                  api_k_0_80_max 0.934062
#               flow_pct_max                  api_k_0_80_max 0.934062
#              flow_pct_mean                   area_above_90 0.933701
#          max_exceedance_90                  api_k_0_80_max 0.933585
#              flow_raw_mean                   area_above_90 0.933247
#              flow_raw_mean                  rain_5day_mean 0.933077
#            api_k_0_80_mean                 api_k_0_90_mean 0.932819
#             rp_approx_mean                  api_k_0_80_max 0.932811
#               flow_pct_max                   rain_3day_max 0.932179
#               flow_raw_max                   rain_3day_max 0.932179
#          max_exceedance_90                   rain_3day_max 0.931979
#              area_above_90                  rain_5day_mean 0.930486
#              rain_1day_max       tp_6h_intensity_mm_hr_max 0.930147
#              flow_raw_mean                  api_k_0_80_max 0.927737
#            api_k_0_70_mean                 api_k_0_85_mean 0.927637
#         storm_within_300km              storm_within_500km 0.927030
#              rain_2day_max                  api_k_0_70_max 0.926432
#              flow_pct_mean                 api_k_0_90_mean 0.926388
#              flow_raw_mean                  api_k_0_85_max 0.926316
#             rain_7day_mean                 api_k_0_90_mean 0.925762
#            api_k_0_90_mean                 api_k_0_95_mean 0.925547
#              rain_1day_max     tp_12h_intensity_mm_hr_mean 0.925295
#             api_k_0_70_max                  api_k_0_85_max 0.925144
#             rp_approx_mean                  api_k_0_70_max 0.923128
#              area_above_90                  rain_4day_mean 0.922846
#             rp_approx_mean                  api_k_0_85_max 0.921138
#              rain_3day_max                impact_proxy_log 0.919006
#              rain_3day_max                   rp_for_impact 0.919006
#              rain_3day_max                    impact_proxy 0.919006
#              rp_approx_max                   rain_3day_max 0.918941
#             rp_approx_mean                 api_k_0_80_mean 0.918233
#              rain_4day_max                  api_k_0_85_max 0.917656
# tp_12h_intensity_mm_hr_max     tp_12h_intensity_mm_hr_mean 0.916300
#              rain_5day_max                  api_k_0_70_max 0.915653
#            api_k_0_80_mean                  api_k_0_90_max 0.915141
#              rain_7day_max                  rain_7day_mean 0.914974
#             storm_wind_max                 storm_wind_mean 0.914872
#      storm_max_wind_kt_max          storm_max_wind_kt_mean 0.914872
#             storm_wind_max          storm_max_wind_kt_mean 0.914872
#            storm_wind_mean           storm_max_wind_kt_max 0.914872
#               flow_pct_max                  rp_approx_mean 0.914608
#               flow_raw_max                  rp_approx_mean 0.914608
#            api_k_0_70_mean                  api_k_0_80_max 0.914317
#          max_exceedance_90                  rp_approx_mean 0.914014
#             rain_14day_max                 rain_14day_mean 0.913769
#              rain_2day_max                   rain_3day_max 0.913639
#              flow_pct_mean                 api_k_0_85_mean 0.913285
#             rp_approx_mean                  rain_2day_mean 0.913243
#              rain_5day_max                  api_k_0_90_max 0.912945
#              rain_7day_max                  api_k_0_80_max 0.912516
#              flow_raw_mean                  api_k_0_90_max 0.912412
#             rain_2day_mean      tp_6h_intensity_mm_hr_mean 0.912192
#              rain_3day_max                  api_k_0_80_max 0.911795
#              rain_1day_max                  rain_1day_mean 0.910130
#                   WS2M_max                       WS2M_mean 0.909837
#            api_k_0_70_mean                  api_k_0_85_max 0.909508
#            api_k_0_85_mean                  api_k_0_90_max 0.909000
#              area_above_90                  rp_approx_mean 0.908892
#              area_above_90                 api_k_0_90_mean 0.908699
#             rain_3day_mean                  rain_5day_mean 0.907979
#              rp_approx_max                  rp_approx_mean 0.907861
#             rp_approx_mean                    impact_proxy 0.907794
#             rp_approx_mean                   rp_for_impact 0.907794
#             rp_approx_mean                impact_proxy_log 0.907794
#             api_k_0_80_max                   rp_for_impact 0.907667
#             api_k_0_80_max                    impact_proxy 0.907667
#             api_k_0_80_max                impact_proxy_log 0.907667
#              rp_approx_max                  api_k_0_80_max 0.907622
#            api_k_0_80_mean                  api_k_0_85_max 0.907109
#              rain_1day_max                   rain_2day_max 0.906989
#              rain_2day_max     tp_12h_intensity_mm_hr_mean 0.906550
#              rain_1day_max      tp_6h_intensity_mm_hr_mean 0.906477
#             rp_approx_mean                  rain_5day_mean 0.906376
#              flow_raw_mean                 api_k_0_85_mean 0.906200
#              rain_7day_max                 api_k_0_80_mean 0.902896
#             api_k_0_95_max                 api_k_0_95_mean 0.901724
#              flow_raw_mean                  rain_2day_mean 0.901061
#              flow_raw_mean                  api_k_0_70_max 0.900988
#             rain_4day_mean                 api_k_0_85_mean 0.900817
#               flow_pct_max                   rain_4day_max 0.899318
#               flow_raw_max                   rain_4day_max 0.899318
#          max_exceedance_90                   rain_4day_max 0.899146
#  tp_6h_intensity_mm_hr_max      tp_6h_intensity_mm_hr_mean 0.898754
#  tp_6h_intensity_mm_hr_max     tp_12h_intensity_mm_hr_mean 0.895051
#              rain_5day_max                 api_k_0_70_mean 0.893963
#             rp_approx_mean                  api_k_0_90_max 0.893284
#             api_k_0_90_max                  api_k_0_95_max 0.892287
#               flow_pct_max      tp_12h_intensity_mm_hr_max 0.891891
#               flow_raw_max      tp_12h_intensity_mm_hr_max 0.891891
#              rain_7day_max                 api_k_0_85_mean 0.891634
#          max_exceedance_90      tp_12h_intensity_mm_hr_max 0.891356
#              rain_2day_max                  rain_2day_mean 0.890963
#             rain_3day_mean                 api_k_0_80_mean 0.890444
#              rain_5day_max                  rain_5day_mean 0.890142
#     n_flood_days_in_window days_to_nearest_flood_in_window 0.890141
#              rain_5day_max                 api_k_0_80_mean 0.889019
#              flow_raw_mean                    flow_pct_max 0.888321
#               flow_raw_max                   flow_raw_mean 0.888321
#            rain_14day_mean                 api_k_0_90_mean 0.888089
#              flow_raw_mean               max_exceedance_90 0.887696
#            api_k_0_70_mean                  api_k_0_90_max 0.887420
#             rain_2day_mean                 api_k_0_70_mean 0.886887
#            api_k_0_90_mean                  api_k_0_95_max 0.886581
#               flow_pct_max                   rain_1day_max 0.886390
#               flow_raw_max                   rain_1day_max 0.886390
#              flow_pct_mean               duration_above_90 0.886064
#          max_exceedance_90                   rain_1day_max 0.886050
#              rain_4day_max                 api_k_0_70_mean 0.885886
# tp_6h_intensity_mm_hr_mean      tp_12h_intensity_mm_hr_max 0.885371
#             api_k_0_70_max                 api_k_0_70_mean 0.884536
#             api_k_0_80_max                 api_k_0_80_mean 0.883984
#              flow_raw_mean                   rain_5day_max 0.883702
#              flow_pct_mean                 api_k_0_80_mean 0.883332
#             rp_approx_mean                   rain_4day_max 0.881745
#             rain_3day_mean                  api_k_0_70_max 0.881621
#              area_above_90                  rain_7day_mean 0.881479
#             rain_2day_mean                  rain_4day_mean 0.881436
#               flow_raw_max                  api_k_0_85_max 0.881415
#               flow_pct_max                  api_k_0_85_max 0.881415
#            rain_14day_mean                 api_k_0_95_mean 0.881280
#          max_exceedance_90                  api_k_0_85_max 0.880846
#             rain_7day_mean                 api_k_0_70_mean 0.880843
#              rain_4day_max                impact_proxy_log 0.879679
#              rain_4day_max                    impact_proxy 0.879679
#              rain_4day_max                   rp_for_impact 0.879679
#              rp_approx_max                   rain_4day_max 0.879588
#              area_above_90                  rain_3day_mean 0.877127
#             rp_approx_mean                   rain_5day_max 0.876970
#              flow_raw_mean                   rain_4day_max 0.876867
#             rp_approx_mean                   rain_3day_max 0.876320
#              rain_3day_max                   rain_5day_max 0.876292
#             api_k_0_85_max                 api_k_0_85_mean 0.876142
#              rain_3day_max                  rain_3day_mean 0.875197
#             rain_4day_mean                  api_k_0_80_max 0.875054
#              rain_2day_max       tp_6h_intensity_mm_hr_max 0.875014
#               flow_pct_max                  rain_2day_mean 0.873839
#               flow_raw_max                  rain_2day_mean 0.873839
#          max_exceedance_90                  rain_2day_mean 0.873720
#              rain_5day_max                  rain_7day_mean 0.873533
#             rain_3day_mean     tp_12h_intensity_mm_hr_mean 0.873113
#              rain_4day_max                  rain_4day_mean 0.872446
#             api_k_0_90_max                 api_k_0_90_mean 0.872292
#              rain_4day_max                  rain_5day_mean 0.872285
#               flow_raw_max     tp_12h_intensity_mm_hr_mean 0.872169
#               flow_pct_max     tp_12h_intensity_mm_hr_mean 0.872169
#             rain_5day_mean                 api_k_0_90_mean 0.872077
#          max_exceedance_90     tp_12h_intensity_mm_hr_mean 0.871758
#               flow_raw_max                  rain_3day_mean 0.870304
#               flow_pct_max                  rain_3day_mean 0.870304
#          max_exceedance_90                  rain_3day_mean 0.870112
# tp_12h_intensity_mm_hr_max                    impact_proxy 0.868475
# tp_12h_intensity_mm_hr_max                impact_proxy_log 0.868475
# tp_12h_intensity_mm_hr_max                   rp_for_impact 0.868475
#              rp_approx_max      tp_12h_intensity_mm_hr_max 0.868428
#             rain_5day_mean                  api_k_0_80_max 0.867579
#              flow_pct_mean                 api_k_0_95_mean 0.867265
#             rain_5day_mean                  api_k_0_85_max 0.866785
#              flow_pct_mean                  rain_7day_mean 0.866646
#              rain_7day_max                 api_k_0_70_mean 0.865543
#             rain_4day_mean                  api_k_0_70_max 0.865189
#              rain_1day_max                  rain_2day_mean 0.865168
#             rain_3day_mean                  api_k_0_80_max 0.863698
#             rp_approx_mean                 api_k_0_85_mean 0.863674
#              rain_1day_max                   rp_for_impact 0.863400
#              rain_1day_max                    impact_proxy 0.863400
#              rain_1day_max                impact_proxy_log 0.863400
#              rp_approx_max                   rain_1day_max 0.863195
#              flow_raw_mean                   rp_approx_max 0.862680
#              flow_raw_mean                impact_proxy_log 0.862610
#              flow_raw_mean                   rp_for_impact 0.862610
#              flow_raw_mean                    impact_proxy 0.862610
#             rain_4day_mean                   rain_5day_max 0.861923
#              rain_4day_max                   rain_7day_max 0.861811
#              rain_3day_max                  rain_4day_mean 0.861778
#             rain_7day_mean                  api_k_0_90_max 0.861677
#             rain_2day_mean                  api_k_0_70_max 0.861580
#             rain_4day_mean                  rain_7day_mean 0.861085
#             rain_5day_mean                   rain_7day_max 0.860484
#              rain_2day_max                  rain_3day_mean 0.859550
#             rain_4day_mean                  api_k_0_85_max 0.858330
#             rain_1day_mean                  rain_3day_mean 0.856809
#              area_above_90                  api_k_0_90_max 0.856671
#              rain_3day_max                 api_k_0_70_mean 0.856206
#              rain_2day_max      tp_6h_intensity_mm_hr_mean 0.855860
#      storm_min_distance_km              storm_within_500km 0.855517
#              flow_raw_mean                   rain_3day_max 0.854752
#              rain_4day_max                  api_k_0_90_max 0.854739
#              flow_pct_mean                  rain_5day_mean 0.854719
#              flow_raw_mean                   rain_7day_max 0.854590
#             api_k_0_85_max                impact_proxy_log 0.854213
#             api_k_0_85_max                    impact_proxy 0.854213
#             api_k_0_85_max                   rp_for_impact 0.854213
#              rp_approx_max                  api_k_0_85_max 0.854210
#              rain_3day_max                  api_k_0_85_max 0.853139
#             rain_3day_mean                   rp_for_impact 0.852236
#             rain_3day_mean                    impact_proxy 0.852236
#             rain_3day_mean                impact_proxy_log 0.852236
#              rp_approx_max                  rain_3day_mean 0.852192
#          duration_above_90                 api_k_0_90_mean 0.852148
#             api_k_0_70_max                  api_k_0_90_max 0.852085
#             rain_5day_mean                  api_k_0_90_max 0.851061

# %%
# create month variable for future handling of missing values
df["month"] = pd.to_datetime(df["center_date"]).dt.month

# remove label/redundant analysis cols.
drop_cols = [
    "window_id", "center_date", "window_start", "window_end",
    "is_flood_event", "n_flood_days_in_window", "days_to_peak_flow",
    "days_to_nearest_flood_in_window", 'flow_raw_max',
    "impact_proxy", "impact_proxy_log", "rp_for_impact", 'rp_approx_max', 'rp_approx_mean',
    "window_n_days", "flow_raw_mean", "flow_pct_mean", "storm_wind_mean",
    "WS2M_mean", "RH2M_mean", 'api_k_0_70_max', 'api_k_0_70_mean', 'api_k_0_80_max',
    'api_k_0_80_mean', 'api_k_0_85_max', 'api_k_0_85_mean',
    "api_k_0_95_max", "api_k_0_95_mean", 'rain_1day_max', 'rain_1day_mean', 
    'rain_2day_max', 'rain_2day_mean', 'rain_4day_mean', 'rain_5day_max', 'rain_5day_mean', 'rain_7day_max',
    'rain_7day_mean', 'rain_14day_max', 'rain_14day_mean', 'tp_6h_intensity_mm_hr_mean',
    'tp_12h_intensity_mm_hr_max', 'tp_12h_intensity_mm_hr_mean', 'storm_max_wind_kt_max',
    'storm_max_wind_kt_mean', 'storm_within_300km', 'storm_within_500km', 'storm_wind_max',
    'max_exceedance_90', 'rain_4day_max', 'api_k_0_90_mean', 'rain_3day_mean'
]

feature_selection_final = df.drop(columns = drop_cols)

feature_selection_final.head()
# Out:
#    flow_pct_max  duration_above_90  area_above_90  rain_3day_max  \
# 0      0.687352                  0            0.0      17.949861
# 1      0.654123                  0            0.0      17.949861
# 2      0.654123                  0            0.0      17.949861
# 3      0.654123                  0            0.0      15.450961
# 4      0.628597                  0            0.0      13.050195
#
#    tp_6h_intensity_mm_hr_max  api_k_0_90_max  storm_min_distance_km  RH2M_max  \
# 0                   1.387644       17.184730                    NaN       NaN
# 1                   1.387644       17.184730                    NaN       NaN
# 2                   1.387644       17.184730                    NaN       NaN
# 3                   0.169324       15.573230                    NaN       NaN
# 4                   0.169324       14.315296                    NaN       NaN
#
#    WS2M_max  month
# 0       NaN      1
# 1       NaN      1
# 2       NaN      1
# 3       NaN      1
# 4       NaN      1

# %% [markdown]
# ## Preprocessing

# %%
# find NAs in dataset
feature_selection_final.isna().sum()
# Out:
# flow_pct_max                     0
# duration_above_90                0
# area_above_90                    0
# rain_3day_max                    0
# tp_6h_intensity_mm_hr_max        0
# api_k_0_90_max                   0
# storm_min_distance_km        12994
# RH2M_max                      2187
# WS2M_max                      2187
# month                            0
# dtype: int64

# %%
# Identify highly correlated feature pairs (|r| > 0.85)
# to avoid redundancy in the feature set
num_df = df.select_dtypes(include=[np.number]).dropna()
corr = num_df.corr(method="spearman")

# upper triangle only to avoid duplicate pairs
upper = corr.abs().where(
    np.triu(np.ones(corr.shape), k=1).astype(bool)
)

high_corr = upper.stack().reset_index()
high_corr.columns = ["variable1", "variable2", "corr"]

high_corr = high_corr[high_corr["corr"] > 0.85]

high_corr = high_corr.sort_values("corr", ascending=False)

print(high_corr.to_string(index=False))
# Out:
#                  variable1                       variable2     corr
#               impact_proxy                impact_proxy_log 1.000000
#               flow_raw_max                    flow_pct_max 1.000000
#            storm_wind_mean          storm_max_wind_kt_mean 1.000000
#             storm_wind_max           storm_max_wind_kt_max 1.000000
#              rp_for_impact                    impact_proxy 1.000000
#              rp_for_impact                impact_proxy_log 1.000000
#              rp_approx_max                    impact_proxy 0.999928
#              rp_approx_max                   rp_for_impact 0.999928
#              rp_approx_max                impact_proxy_log 0.999928
#               flow_pct_max               max_exceedance_90 0.999436
#               flow_raw_max               max_exceedance_90 0.999436
#             rain_4day_mean                 api_k_0_70_mean 0.987587
#            api_k_0_80_mean                 api_k_0_85_mean 0.986692
#             api_k_0_80_max                  api_k_0_85_max 0.986344
#              flow_raw_mean                  rp_approx_mean 0.982340
#              flow_raw_mean                 api_k_0_70_mean 0.981335
#               flow_pct_max                  api_k_0_70_max 0.980697
#               flow_raw_max                  api_k_0_70_max 0.980697
#          max_exceedance_90                  api_k_0_70_max 0.980315
#               flow_raw_max                   rp_approx_max 0.979570
#               flow_pct_max                   rp_approx_max 0.979570
#               flow_raw_max                impact_proxy_log 0.979499
#               flow_raw_max                    impact_proxy 0.979499
#               flow_raw_max                   rp_for_impact 0.979499
#               flow_pct_max                impact_proxy_log 0.979499
#               flow_pct_max                    impact_proxy 0.979499
#               flow_pct_max                   rp_for_impact 0.979499
#          max_exceedance_90                impact_proxy_log 0.979042
#          max_exceedance_90                    impact_proxy 0.979042
#          max_exceedance_90                   rp_for_impact 0.979042
#             api_k_0_85_max                  api_k_0_90_max 0.979005
#          max_exceedance_90                   rp_approx_max 0.978971
#             rain_4day_mean                  rain_5day_mean 0.977713
#            api_k_0_85_mean                 api_k_0_90_mean 0.976460
# tp_6h_intensity_mm_hr_mean     tp_12h_intensity_mm_hr_mean 0.975680
#             rain_5day_mean                 api_k_0_80_mean 0.974531
#            api_k_0_70_mean                 api_k_0_80_mean 0.973632
#             rain_5day_mean                 api_k_0_70_mean 0.971876
#             rain_3day_mean                  rain_4day_mean 0.971796
#             api_k_0_70_max                  api_k_0_80_max 0.970645
#             rain_3day_mean                 api_k_0_70_mean 0.964899
#             api_k_0_70_max                   rp_for_impact 0.964886
#             api_k_0_70_max                    impact_proxy 0.964886
#             api_k_0_70_max                impact_proxy_log 0.964886
#              rp_approx_max                  api_k_0_70_max 0.964838
#              rain_4day_max                   rain_5day_max 0.964540
#             rp_approx_mean                 api_k_0_70_mean 0.964119
#  tp_6h_intensity_mm_hr_max      tp_12h_intensity_mm_hr_max 0.962461
#             rain_2day_mean                  rain_3day_mean 0.961235
#              flow_raw_mean                  rain_4day_mean 0.960621
#              rain_3day_max                  api_k_0_70_max 0.959600
#             rain_7day_mean                 api_k_0_85_mean 0.957184
#              flow_raw_mean                  rain_3day_mean 0.956784
#             rain_1day_mean     tp_12h_intensity_mm_hr_mean 0.956199
#              rain_5day_max                  api_k_0_80_max 0.956129
#              area_above_90                 api_k_0_80_mean 0.954636
#               flow_raw_max                   rain_2day_max 0.954168
#               flow_pct_max                   rain_2day_max 0.954168
#          max_exceedance_90                   rain_2day_max 0.953872
#             rain_1day_mean                  rain_2day_mean 0.953799
#             rp_approx_mean                  rain_3day_mean 0.952190
#             rain_4day_mean                 api_k_0_80_mean 0.952108
#              rain_5day_max                  api_k_0_85_max 0.952037
#              rain_4day_max                  api_k_0_70_max 0.951537
#              flow_raw_mean                 api_k_0_80_mean 0.951035
#              rain_4day_max                  api_k_0_80_max 0.951008
#             rain_1day_mean      tp_6h_intensity_mm_hr_mean 0.949718
#             rain_2day_mean     tp_12h_intensity_mm_hr_mean 0.948497
#              rain_3day_max                   rain_4day_max 0.947863
#             rain_7day_mean                 api_k_0_80_mean 0.947708
#             rain_5day_mean                 api_k_0_85_mean 0.944763
#              area_above_90                 api_k_0_85_mean 0.944116
#             rp_approx_mean                  rain_4day_mean 0.942727
#              rain_7day_max                  api_k_0_85_max 0.942645
#              rain_2day_max      tp_12h_intensity_mm_hr_max 0.941737
#              rain_7day_max                  api_k_0_90_max 0.941516
#             api_k_0_80_max                  api_k_0_90_max 0.941249
#             rain_5day_mean                  rain_7day_mean 0.940052
#              rain_5day_max                   rain_7day_max 0.937890
#              area_above_90                 api_k_0_70_mean 0.937714
#              rain_2day_max                impact_proxy_log 0.936105
#              rain_2day_max                    impact_proxy 0.936105
#              rain_2day_max                   rp_for_impact 0.936105
#              rp_approx_max                   rain_2day_max 0.936019
#              rain_1day_max      tp_12h_intensity_mm_hr_max 0.934422
#               flow_raw_max                  api_k_0_80_max 0.934062
#               flow_pct_max                  api_k_0_80_max 0.934062
#              flow_pct_mean                   area_above_90 0.933701
#          max_exceedance_90                  api_k_0_80_max 0.933585
#              flow_raw_mean                   area_above_90 0.933247
#              flow_raw_mean                  rain_5day_mean 0.933077
#            api_k_0_80_mean                 api_k_0_90_mean 0.932819
#             rp_approx_mean                  api_k_0_80_max 0.932811
#               flow_pct_max                   rain_3day_max 0.932179
#               flow_raw_max                   rain_3day_max 0.932179
#          max_exceedance_90                   rain_3day_max 0.931979
#              area_above_90                  rain_5day_mean 0.930486
#              rain_1day_max       tp_6h_intensity_mm_hr_max 0.930147
#              flow_raw_mean                  api_k_0_80_max 0.927737
#            api_k_0_70_mean                 api_k_0_85_mean 0.927637
#         storm_within_300km              storm_within_500km 0.927030
#              rain_2day_max                  api_k_0_70_max 0.926432
#              flow_pct_mean                 api_k_0_90_mean 0.926388
#              flow_raw_mean                  api_k_0_85_max 0.926316
#             rain_7day_mean                 api_k_0_90_mean 0.925762
#            api_k_0_90_mean                 api_k_0_95_mean 0.925547
#              rain_1day_max     tp_12h_intensity_mm_hr_mean 0.925295
#             api_k_0_70_max                  api_k_0_85_max 0.925144
#             rp_approx_mean                  api_k_0_70_max 0.923128
#              area_above_90                  rain_4day_mean 0.922846
#             rp_approx_mean                  api_k_0_85_max 0.921138
#              rain_3day_max                impact_proxy_log 0.919006
#              rain_3day_max                   rp_for_impact 0.919006
#              rain_3day_max                    impact_proxy 0.919006
#              rp_approx_max                   rain_3day_max 0.918941
#             rp_approx_mean                 api_k_0_80_mean 0.918233
#              rain_4day_max                  api_k_0_85_max 0.917656
# tp_12h_intensity_mm_hr_max     tp_12h_intensity_mm_hr_mean 0.916300
#              rain_5day_max                  api_k_0_70_max 0.915653
#            api_k_0_80_mean                  api_k_0_90_max 0.915141
#              rain_7day_max                  rain_7day_mean 0.914974
#             storm_wind_max                 storm_wind_mean 0.914872
#      storm_max_wind_kt_max          storm_max_wind_kt_mean 0.914872
#             storm_wind_max          storm_max_wind_kt_mean 0.914872
#            storm_wind_mean           storm_max_wind_kt_max 0.914872
#               flow_pct_max                  rp_approx_mean 0.914608
#               flow_raw_max                  rp_approx_mean 0.914608
#            api_k_0_70_mean                  api_k_0_80_max 0.914317
#          max_exceedance_90                  rp_approx_mean 0.914014
#             rain_14day_max                 rain_14day_mean 0.913769
#              rain_2day_max                   rain_3day_max 0.913639
#              flow_pct_mean                 api_k_0_85_mean 0.913285
#             rp_approx_mean                  rain_2day_mean 0.913243
#              rain_5day_max                  api_k_0_90_max 0.912945
#              rain_7day_max                  api_k_0_80_max 0.912516
#              flow_raw_mean                  api_k_0_90_max 0.912412
#             rain_2day_mean      tp_6h_intensity_mm_hr_mean 0.912192
#              rain_3day_max                  api_k_0_80_max 0.911795
#              rain_1day_max                  rain_1day_mean 0.910130
#                   WS2M_max                       WS2M_mean 0.909837
#            api_k_0_70_mean                  api_k_0_85_max 0.909508
#            api_k_0_85_mean                  api_k_0_90_max 0.909000
#              area_above_90                  rp_approx_mean 0.908892
#              area_above_90                 api_k_0_90_mean 0.908699
#             rain_3day_mean                  rain_5day_mean 0.907979
#              rp_approx_max                  rp_approx_mean 0.907861
#             rp_approx_mean                    impact_proxy 0.907794
#             rp_approx_mean                   rp_for_impact 0.907794
#             rp_approx_mean                impact_proxy_log 0.907794
#             api_k_0_80_max                   rp_for_impact 0.907667
#             api_k_0_80_max                    impact_proxy 0.907667
#             api_k_0_80_max                impact_proxy_log 0.907667
#              rp_approx_max                  api_k_0_80_max 0.907622
#            api_k_0_80_mean                  api_k_0_85_max 0.907109
#              rain_1day_max                   rain_2day_max 0.906989
#              rain_2day_max     tp_12h_intensity_mm_hr_mean 0.906550
#              rain_1day_max      tp_6h_intensity_mm_hr_mean 0.906477
#             rp_approx_mean                  rain_5day_mean 0.906376
#              flow_raw_mean                 api_k_0_85_mean 0.906200
#              rain_7day_max                 api_k_0_80_mean 0.902896
#             api_k_0_95_max                 api_k_0_95_mean 0.901724
#              flow_raw_mean                  rain_2day_mean 0.901061
#              flow_raw_mean                  api_k_0_70_max 0.900988
#             rain_4day_mean                 api_k_0_85_mean 0.900817
#               flow_pct_max                   rain_4day_max 0.899318
#               flow_raw_max                   rain_4day_max 0.899318
#          max_exceedance_90                   rain_4day_max 0.899146
#  tp_6h_intensity_mm_hr_max      tp_6h_intensity_mm_hr_mean 0.898754
#  tp_6h_intensity_mm_hr_max     tp_12h_intensity_mm_hr_mean 0.895051
#              rain_5day_max                 api_k_0_70_mean 0.893963
#             rp_approx_mean                  api_k_0_90_max 0.893284
#             api_k_0_90_max                  api_k_0_95_max 0.892287
#               flow_pct_max      tp_12h_intensity_mm_hr_max 0.891891
#               flow_raw_max      tp_12h_intensity_mm_hr_max 0.891891
#              rain_7day_max                 api_k_0_85_mean 0.891634
#          max_exceedance_90      tp_12h_intensity_mm_hr_max 0.891356
#              rain_2day_max                  rain_2day_mean 0.890963
#             rain_3day_mean                 api_k_0_80_mean 0.890444
#              rain_5day_max                  rain_5day_mean 0.890142
#     n_flood_days_in_window days_to_nearest_flood_in_window 0.890141
#              rain_5day_max                 api_k_0_80_mean 0.889019
#              flow_raw_mean                    flow_pct_max 0.888321
#               flow_raw_max                   flow_raw_mean 0.888321
#            rain_14day_mean                 api_k_0_90_mean 0.888089
#              flow_raw_mean               max_exceedance_90 0.887696
#            api_k_0_70_mean                  api_k_0_90_max 0.887420
#             rain_2day_mean                 api_k_0_70_mean 0.886887
#            api_k_0_90_mean                  api_k_0_95_max 0.886581
#               flow_pct_max                   rain_1day_max 0.886390
#               flow_raw_max                   rain_1day_max 0.886390
#              flow_pct_mean               duration_above_90 0.886064
#          max_exceedance_90                   rain_1day_max 0.886050
#              rain_4day_max                 api_k_0_70_mean 0.885886
# tp_6h_intensity_mm_hr_mean      tp_12h_intensity_mm_hr_max 0.885371
#             api_k_0_70_max                 api_k_0_70_mean 0.884536
#             api_k_0_80_max                 api_k_0_80_mean 0.883984
#              flow_raw_mean                   rain_5day_max 0.883702
#              flow_pct_mean                 api_k_0_80_mean 0.883332
#             rp_approx_mean                   rain_4day_max 0.881745
#             rain_3day_mean                  api_k_0_70_max 0.881621
#              area_above_90                  rain_7day_mean 0.881479
#             rain_2day_mean                  rain_4day_mean 0.881436
#               flow_raw_max                  api_k_0_85_max 0.881415
#               flow_pct_max                  api_k_0_85_max 0.881415
#            rain_14day_mean                 api_k_0_95_mean 0.881280
#          max_exceedance_90                  api_k_0_85_max 0.880846
#             rain_7day_mean                 api_k_0_70_mean 0.880843
#              rain_4day_max                impact_proxy_log 0.879679
#              rain_4day_max                    impact_proxy 0.879679
#              rain_4day_max                   rp_for_impact 0.879679
#              rp_approx_max                   rain_4day_max 0.879588
#              area_above_90                  rain_3day_mean 0.877127
#             rp_approx_mean                   rain_5day_max 0.876970
#              flow_raw_mean                   rain_4day_max 0.876867
#             rp_approx_mean                   rain_3day_max 0.876320
#              rain_3day_max                   rain_5day_max 0.876292
#             api_k_0_85_max                 api_k_0_85_mean 0.876142
#              rain_3day_max                  rain_3day_mean 0.875197
#             rain_4day_mean                  api_k_0_80_max 0.875054
#              rain_2day_max       tp_6h_intensity_mm_hr_max 0.875014
#               flow_pct_max                  rain_2day_mean 0.873839
#               flow_raw_max                  rain_2day_mean 0.873839
#          max_exceedance_90                  rain_2day_mean 0.873720
#              rain_5day_max                  rain_7day_mean 0.873533
#             rain_3day_mean     tp_12h_intensity_mm_hr_mean 0.873113
#              rain_4day_max                  rain_4day_mean 0.872446
#             api_k_0_90_max                 api_k_0_90_mean 0.872292
#              rain_4day_max                  rain_5day_mean 0.872285
#               flow_raw_max     tp_12h_intensity_mm_hr_mean 0.872169
#               flow_pct_max     tp_12h_intensity_mm_hr_mean 0.872169
#             rain_5day_mean                 api_k_0_90_mean 0.872077
#          max_exceedance_90     tp_12h_intensity_mm_hr_mean 0.871758
#               flow_raw_max                  rain_3day_mean 0.870304
#               flow_pct_max                  rain_3day_mean 0.870304
#          max_exceedance_90                  rain_3day_mean 0.870112
# tp_12h_intensity_mm_hr_max                    impact_proxy 0.868475
# tp_12h_intensity_mm_hr_max                impact_proxy_log 0.868475
# tp_12h_intensity_mm_hr_max                   rp_for_impact 0.868475
#              rp_approx_max      tp_12h_intensity_mm_hr_max 0.868428
#             rain_5day_mean                  api_k_0_80_max 0.867579
#              flow_pct_mean                 api_k_0_95_mean 0.867265
#             rain_5day_mean                  api_k_0_85_max 0.866785
#              flow_pct_mean                  rain_7day_mean 0.866646
#              rain_7day_max                 api_k_0_70_mean 0.865543
#             rain_4day_mean                  api_k_0_70_max 0.865189
#              rain_1day_max                  rain_2day_mean 0.865168
#             rain_3day_mean                  api_k_0_80_max 0.863698
#             rp_approx_mean                 api_k_0_85_mean 0.863674
#              rain_1day_max                   rp_for_impact 0.863400
#              rain_1day_max                    impact_proxy 0.863400
#              rain_1day_max                impact_proxy_log 0.863400
#              rp_approx_max                   rain_1day_max 0.863195
#              flow_raw_mean                   rp_approx_max 0.862680
#              flow_raw_mean                impact_proxy_log 0.862610
#              flow_raw_mean                   rp_for_impact 0.862610
#              flow_raw_mean                    impact_proxy 0.862610
#             rain_4day_mean                   rain_5day_max 0.861923
#              rain_4day_max                   rain_7day_max 0.861811
#              rain_3day_max                  rain_4day_mean 0.861778
#             rain_7day_mean                  api_k_0_90_max 0.861677
#             rain_2day_mean                  api_k_0_70_max 0.861580
#             rain_4day_mean                  rain_7day_mean 0.861085
#             rain_5day_mean                   rain_7day_max 0.860484
#              rain_2day_max                  rain_3day_mean 0.859550
#             rain_4day_mean                  api_k_0_85_max 0.858330
#             rain_1day_mean                  rain_3day_mean 0.856809
#              area_above_90                  api_k_0_90_max 0.856671
#              rain_3day_max                 api_k_0_70_mean 0.856206
#              rain_2day_max      tp_6h_intensity_mm_hr_mean 0.855860
#      storm_min_distance_km              storm_within_500km 0.855517
#              flow_raw_mean                   rain_3day_max 0.854752
#              rain_4day_max                  api_k_0_90_max 0.854739
#              flow_pct_mean                  rain_5day_mean 0.854719
#              flow_raw_mean                   rain_7day_max 0.854590
#             api_k_0_85_max                impact_proxy_log 0.854213
#             api_k_0_85_max                    impact_proxy 0.854213
#             api_k_0_85_max                   rp_for_impact 0.854213
#              rp_approx_max                  api_k_0_85_max 0.854210
#              rain_3day_max                  api_k_0_85_max 0.853139
#             rain_3day_mean                   rp_for_impact 0.852236
#             rain_3day_mean                    impact_proxy 0.852236
#             rain_3day_mean                impact_proxy_log 0.852236
#              rp_approx_max                  rain_3day_mean 0.852192
#          duration_above_90                 api_k_0_90_mean 0.852148
#             api_k_0_70_max                  api_k_0_90_max 0.852085
#             rain_5day_mean                  api_k_0_90_max 0.851061

# %%
# FILL MISSING VALUES
D_raw = feature_selection_final.copy()

# fill missing meteoroligical values with monthly median
# original data from NASA starts in 1981
# monthly median to maintain seasonality
met_cols = [
    "RH2M_max", "WS2M_max"
]
for col in met_cols:
    D_raw[col] = D_raw[col].fillna(D_raw.groupby("month")[col].transform("median"))

# remove month col. (no longer needed)
D_raw = D_raw.drop(columns = "month")

# fill missing values in storm distance
# if there is no storm (hurricane/tropical cyclone) in the Atalantic coded as NA
# set NA distances to max distance + buffer
max_distance = D_raw["storm_min_distance_km"].max() # 13616.956 km
buffer = max_distance + 1000
D_raw["storm_min_distance_km"] = D_raw["storm_min_distance_km"].fillna(buffer) # fill missing
D_raw["no_storm"] = (D_raw["storm_min_distance_km"] > max_distance).astype(int)

# check
D_raw.isna().sum()
# Out:
# flow_pct_max                 0
# duration_above_90            0
# area_above_90                0
# rain_3day_max                0
# tp_6h_intensity_mm_hr_max    0
# api_k_0_90_max               0
# storm_min_distance_km        0
# RH2M_max                     0
# WS2M_max                     0
# no_storm                     0
# dtype: int64

# %%
# TRANSFORMATIONS

# view distributions
D_raw.hist(figsize = (14, 10), bins = 40)
plt.show() # skewed: rain_3day_max, tp_6h_mm_hr_max, api_k_0_90_max, area_above_90

D = D_raw.copy()

# transformations
D["rain_3day_max"] = np.log1p(D["rain_3day_max"])
D["tp_6h_intensity_mm_hr_max"] = np.log1p(D["tp_6h_intensity_mm_hr_max"])
D["api_k_0_90_max"] = np.log1p(D["api_k_0_90_max"])
D["area_above_90"] = np.log1p(D["area_above_90"])
D = D.drop(columns = "no_storm") # drop labeling variable
D.head()
# Out:
#    flow_pct_max  duration_above_90  area_above_90  rain_3day_max  \
# 0      0.687352                  0            0.0       2.941797
# 1      0.654123                  0            0.0       2.941797
# 2      0.654123                  0            0.0       2.941797
# 3      0.654123                  0            0.0       2.800384
# 4      0.628597                  0            0.0       2.642636
#
#    tp_6h_intensity_mm_hr_max  api_k_0_90_max  storm_min_distance_km  RH2M_max  \
# 0                   0.870307        2.900582           14616.956048     86.55
# 1                   0.870307        2.900582           14616.956048     86.55
# 2                   0.870307        2.900582           14616.956048     86.55
# 3                   0.156425        2.807789           14616.956048     86.55
# 4                   0.156425        2.728852           14616.956048     86.55
#
#    WS2M_max
# 0      2.76
# 1      2.76
# 2      2.76
# 3      2.76
# 4      2.76

# %% [markdown]
# # Analysis

# %% [markdown]
# ### PCA

# %%
# standardize
scaler = StandardScaler()   
D_scaled = scaler.fit_transform(D)

# pca on normalized
pca_D_scaled = PCA() 
pca_transformed_D_scaled = pca_D_scaled.fit_transform(D_scaled)

# store component variance
explained_var = pca_D_scaled.explained_variance_ratio_
cumulative_var = np.cumsum(explained_var)

# %%
# initialize
total_var = 0
count = 0

# iterate through components till 90% of variance is reached
while total_var < 0.90:
    total_var += explained_var[count]
    count += 1

print(f"In order to capture at least 90% of the variance, {count} principal components are needed.")
# Out:
# In order to capture at least 90% of the variance, 5 principal components are needed.

# %%
var_components_1_2 = explained_var[0] + explained_var[1]
print(f"The fraction of variance captured by PC1 and PC2 is {round(var_components_1_2, 4)}.")
# Out:
# The fraction of variance captured by PC1 and PC2 is 0.6889.

# %%
print(explained_var)
# Out:
# [0.53507213 0.15380512 0.09941002 0.07484773 0.06917547 0.03923456
#  0.01669946 0.00732203 0.00443348]

# %%
# PLOT CAPTURED VARIANCE FIGURES

# X axis: number of components (1 to n)
components = np.arange(1, len(cumulative_var) + 1)

# Plot
plt.plot(components, cumulative_var, marker='o')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title("PCA of Flood-Related Features", fontsize = 10)
plt.suptitle('Cumulative Explained Variance by Principal Components')
plt.grid() # add gridlines

# Plot
plt.show()
plt.plot(components, explained_var, marker='o')
plt.xlabel('Number of Principal Components')
plt.ylabel('Explained Variance')
plt.suptitle('Explained Variance by Principal Component')
plt.title("PCA of Flood-Related Features", fontsize = 10)
plt.grid() # add gridlines

# %%
# PLOT PCA COMPONENTS
# bring back label columns for coloring (not used in PCA itself)
plot_df = D.copy()
plot_df["no_storm"] = D_raw["no_storm"].values
plot_df["is_flood_event"] = df["is_flood_event"]
plot_df["impact_proxy"] = df["impact_proxy"]
sizes = (plot_df["impact_proxy"] / plot_df["impact_proxy"].max()) * 100  # scale point size by impact severity

flood = plot_df["is_flood_event"] == 1
no_flood = plot_df["is_flood_event"] == 0

# PC1 vs. PC2
plt.scatter(pca_transformed_D_scaled[flood, 0], pca_transformed_D_scaled[flood, 1], alpha = 0.3, s = sizes[flood], label = "Flood")
plt.scatter(pca_transformed_D_scaled[no_flood, 0], pca_transformed_D_scaled[no_flood, 1], alpha = 0.05, s = sizes[no_flood], label = "No Flood")
plt.legend()
plt.suptitle('PC1 vs. PC2')
plt.title("Colored by Flood Event, Sized by Impact", fontsize = 10)
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.savefig("figure_pc1_2.png", dpi = 300, bbox_inches = "tight")

# PC1 vs. PC3
plt.show()
plt.scatter(pca_transformed_D_scaled[flood, 0], pca_transformed_D_scaled[flood, 2], alpha = 0.3, s = sizes[flood], label = "Flood")
plt.scatter(pca_transformed_D_scaled[no_flood, 0], pca_transformed_D_scaled[no_flood, 2], alpha = 0.05, s = sizes[no_flood], label = "No Flood")
plt.legend()
plt.suptitle('PC1 vs. PC3')
plt.title("Colored by Flood Event, Sized by Impact", fontsize = 10)
plt.xlabel("PC1")
plt.ylabel("PC3")
plt.savefig("figure_pc1_3.png", dpi = 300, bbox_inches = "tight")

# PC2 vs. PC3
plt.show()
plt.scatter(pca_transformed_D_scaled[flood, 1], pca_transformed_D_scaled[flood, 2], alpha = 0.3, s = sizes[flood], label = "Flood")
plt.scatter(pca_transformed_D_scaled[no_flood, 1], pca_transformed_D_scaled[no_flood, 2], alpha = 0.05, s = sizes[no_flood], label = "No Flood")
plt.legend()
plt.suptitle('PC2 vs. PC3')
plt.title("Colored by Flood Event, Sized by Impact", fontsize = 10)
plt.xlabel("PC2")
plt.ylabel("PC3")
plt.savefig("figure_pc2_3.png", dpi=300, bbox_inches="tight")

# %%
# PLOT PCA COMPONENTS
# Look at relationship w/ storm

# PC1 vs. PC2
plt.show()
no_storm = plot_df["no_storm"] == 1 # color by storm/no-storm presence
storm = plot_df["no_storm"] == 0
plt.scatter(pca_transformed_D_scaled[no_storm, 0], pca_transformed_D_scaled[no_storm, 1], alpha = 0.05, label = "No Storm")
plt.scatter(pca_transformed_D_scaled[storm, 0], pca_transformed_D_scaled[storm, 1], alpha = 0.05, label = "Storm")
plt.legend()
plt.suptitle('PCA-Transformed Normalized Flood Data Using First Two Dimensions')
plt.title("Colored by Storm Presence", fontsize = 10)
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.savefig("figure_pc1_2_storm.png", dpi = 300, bbox_inches = "tight") # save as png

# PC1 vs. PC3
plt.show()
no_storm = plot_df["no_storm"] == 1 # color by storm/no-storm presence
storm = plot_df["no_storm"] == 0
plt.scatter(pca_transformed_D_scaled[no_storm, 0], pca_transformed_D_scaled[no_storm, 2], alpha = 0.05, label = "No Storm")
plt.scatter(pca_transformed_D_scaled[storm, 0], pca_transformed_D_scaled[storm, 2], alpha = 0.05, label = "Storm")
plt.legend()
plt.suptitle('PCA-Transformed Normalized Flood Data Using First Two Dimensions')
plt.title("Colored by Storm Presence", fontsize = 10)
plt.xlabel("PC1")
plt.ylabel("PC3")
plt.savefig("figure_pc1_3_storm.png", dpi = 300, bbox_inches = "tight") # save as png

# PC2 vs. PC3
plt.show()
no_storm = plot_df["no_storm"] == 1 # color by storm/no-storm presence
storm = plot_df["no_storm"] == 0
plt.scatter(pca_transformed_D_scaled[no_storm, 1], pca_transformed_D_scaled[no_storm, 2], alpha = 0.05, label = "No Storm")
plt.scatter(pca_transformed_D_scaled[storm, 1], pca_transformed_D_scaled[storm, 2], alpha = 0.05, label = "Storm")
plt.legend()
plt.suptitle('PCA-Transformed Normalized Flood Data Using First Two Dimensions')
plt.title("Colored by Storm Presence", fontsize = 10)
plt.xlabel("PC1")
plt.ylabel("PC3")
plt.savefig("figure_pc2_3_storm.png", dpi = 300, bbox_inches = "tight") # save as png

# %%
# VIEW PCA COMPONENTS
# store pca components & variable weights
components_pca = pd.DataFrame(pca_D_scaled.components_.T, index = D.columns)

# look at var. weights in each pc
pc1 = components_pca[0]
print("PC1")
print(pc1)
print()

print("PC2")
pc2 = components_pca[1]
print(pc2)
print()

print("PC3")
pc3 = components_pca[2]
print(pc3)
print()

print(explained_var)
# Out:
# PC1
# flow_pct_max                 0.396186
# duration_above_90            0.367729
# area_above_90                0.358347
# rain_3day_max                0.402185
# tp_6h_intensity_mm_hr_max    0.372073
# api_k_0_90_max               0.415404
# storm_min_distance_km       -0.189770
# RH2M_max                     0.263519
# WS2M_max                     0.034548
# Name: 0, dtype: float64
#
# PC2
# flow_pct_max                -0.150314
# duration_above_90            0.176891
# area_above_90                0.224996
# rain_3day_max                0.094612
# tp_6h_intensity_mm_hr_max    0.221478
# api_k_0_90_max              -0.169781
# storm_min_distance_km        0.473960
# RH2M_max                    -0.268764
# WS2M_max                     0.715396
# Name: 1, dtype: float64
#
# PC3
# flow_pct_max                -0.297785
# duration_above_90            0.509110
# area_above_90                0.528543
# rain_3day_max               -0.250798
# tp_6h_intensity_mm_hr_max   -0.219155
# api_k_0_90_max              -0.093161
# storm_min_distance_km       -0.312462
# RH2M_max                    -0.341594
# WS2M_max                    -0.197097
# Name: 2, dtype: float64
#
# [0.53507213 0.15380512 0.09941002 0.07484773 0.06917547 0.03923456
#  0.01669946 0.00732203 0.00443348]

# %%
# show the top 5 features by absolute loading for each PC
# what each component represents physically
n_top = 5

pcs = ["PC1", "PC2", "PC3"]

for pc_idx, pc_name in enumerate(pcs):
    loadings = components_pca[pc_idx].abs().sort_values(ascending=False)
    print("----{}: Top {} features ---".format(pc_name, n_top))
    print(loadings.head(n_top).to_string())
    print()
# Out:
# ----PC1: Top 5 features ---
# api_k_0_90_max               0.415404
# rain_3day_max                0.402185
# flow_pct_max                 0.396186
# tp_6h_intensity_mm_hr_max    0.372073
# duration_above_90            0.367729
#
# ----PC2: Top 5 features ---
# WS2M_max                     0.715396
# storm_min_distance_km        0.473960
# RH2M_max                     0.268764
# area_above_90                0.224996
# tp_6h_intensity_mm_hr_max    0.221478
#
# ----PC3: Top 5 features ---
# area_above_90            0.528543
# duration_above_90        0.509110
# RH2M_max                 0.341594
# storm_min_distance_km    0.312462
# flow_pct_max             0.297785

# %% [markdown]
# ## Kernal PCA

# %%
# STANDARDIZE FEATURES

scaler = StandardScaler()
D_scaled = scaler.fit_transform(D)

# RUN KERNEL PCA

kpca = KernelPCA(
    n_components=3,
    kernel="rbf",
    gamma=0.35,
    random_state=42
)

D_kpca = kpca.fit_transform(D_scaled)

# STORE KERNEL PCA COMPONENTS

kpca_df = pd.DataFrame(
    D_kpca,
    columns=["KPC1", "KPC2", "KPC3"],
    index=D.index
)

# bring back labels for plotting
kpca_df["is_flood_event"] = df.loc[D.index, "is_flood_event"].values
kpca_df["impact_proxy"] = df.loc[D.index, "impact_proxy"].values

# SCALE POINT SIZE BY IMPACT

sizes = (kpca_df["impact_proxy"] / kpca_df["impact_proxy"].max()) * 100

flood = kpca_df["is_flood_event"] == 1
no_flood = kpca_df["is_flood_event"] == 0

# KPC1 VS KPC2

plt.figure(figsize=(8,6))

plt.scatter(
    kpca_df.loc[flood, "KPC1"],
    kpca_df.loc[flood, "KPC2"],
    alpha=0.3,
    s=sizes[flood],
    label="Flood"
)

plt.scatter(
    kpca_df.loc[no_flood, "KPC1"],
    kpca_df.loc[no_flood, "KPC2"],
    alpha=0.05,
    s=sizes[no_flood],
    label="No Flood"
)

plt.legend()
plt.suptitle("KPC1 vs. KPC2")
plt.title("Kernel PCA Projection: Colored by Flood Event, Sized by Impact", fontsize=10)
plt.xlabel("KPC1")
plt.ylabel("KPC2")
plt.tight_layout()
plt.savefig("figure_kpca1_2.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
# KPC1 VS KPC3

plt.figure(figsize=(8,6))

plt.scatter(
    kpca_df.loc[flood, "KPC1"],
    kpca_df.loc[flood, "KPC3"],
    alpha=0.3,
    s=sizes[flood],
    label="Flood"
)

plt.scatter(
    kpca_df.loc[no_flood, "KPC1"],
    kpca_df.loc[no_flood, "KPC3"],
    alpha=0.35,
    s=sizes[no_flood],
    label="No Flood"
)

plt.legend()
plt.suptitle("KPC1 vs. KPC3")
plt.title("Kernel PCA Projection: Colored by Flood Event, Sized by Impact", fontsize=10)
plt.xlabel("KPC1")
plt.ylabel("KPC3")
plt.tight_layout()
plt.savefig("figure_kpca1_3.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
# KPC2 VS KPC3

plt.figure(figsize=(8,6))

plt.scatter(
    kpca_df.loc[flood, "KPC2"],
    kpca_df.loc[flood, "KPC3"],
    alpha=0.35,
    s=sizes[flood],
    label="Flood"
)

plt.scatter(
    kpca_df.loc[no_flood, "KPC2"],
    kpca_df.loc[no_flood, "KPC3"],
    alpha=0.35,
    s=sizes[no_flood],
    label="No Flood"
)

plt.legend()
plt.suptitle("KPC2 vs. KPC3")
plt.title("Kernel PCA Projection: Colored by Flood Event, Sized by Impact", fontsize=10)
plt.xlabel("KPC2")
plt.ylabel("KPC3")
plt.tight_layout()
plt.savefig("figure_kpca2_3.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Clustering
# ### K-Means & DBSCAN

# %%
# Objective function value for each of the k value plot
# use first 3 PCs (~80% variance)
D_cluster = pca_transformed_D_scaled[:, :3] # PC1-5 minimal clustering benefit with added complexity
k_values = range(1, 10)
k_obj_pca = []

# iterate through each k-val
for k in k_values: 
    kmeans = KMeans(n_clusters = k, init = 'k-means++', n_init = 10) # run k-means algorithm
    kmeans.fit(D_cluster)
    k_obj_pca.append(kmeans.inertia_) # store
        

# plot elbow curve
plt.figure()
plt.plot(k_values, k_obj_pca, marker='o')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Objective Function')
plt.title('Elbow Plot: K-Means on PCA-Reduced Data')
plt.grid()
plt.savefig("figure_k_means_elbow.png", dpi = 300, bbox_inches = "tight") # save as png

# %%
# Run k-means with k = 2 since it has best silhoutte score
kmeans = KMeans(n_clusters = 2, init = 'k-means++', max_iter = 300, random_state = 0) # run k-means algorithm
pred_cluster_labels = kmeans.fit_predict(D_cluster) # index of the cluster each sample belongs to
kmeans.cluster_centers_  # coordinates of cluster centers

# scatter plot of clusters & centroids
# PC1 vs. PC2
plt.scatter(D_cluster[:,0], D_cluster[:, 1], c=pred_cluster_labels, alpha = 0.05)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c = 'red')
plt.title("PC1 vs. PC2")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.savefig("figure_k_means_clustering_pc1_2.png", dpi = 300, bbox_inches = "tight") # save as png

# PC1 vs. PC3
plt.show()
plt.scatter(D_cluster[:,0], D_cluster[:, 2], c=pred_cluster_labels, alpha = 0.05)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 2], c = 'red')
plt.title("PC1 vs. PC3")
plt.xlabel("PC1")
plt.ylabel("PC3")
plt.savefig("figure_k_means_clustering_pc1_3.png", dpi = 300, bbox_inches = "tight") # save as png

# PC2 vs. PC3
plt.show()
plt.scatter(D_cluster[:,1], D_cluster[:, 2], c=pred_cluster_labels, alpha = 0.05)
plt.scatter(kmeans.cluster_centers_[:, 1], kmeans.cluster_centers_[:, 2], c = 'red')
plt.title("PC2 vs. PC3")
plt.xlabel("PC2")
plt.ylabel("PC3")
plt.savefig("figure_k_means_clustering_pc2_3.png", dpi = 300, bbox_inches = "tight") # save as png

# calc mean impact and flooding within each cluster
plot_df["cluster"] = pred_cluster_labels
plot_df.groupby("cluster")[["impact_proxy", "is_flood_event"]].mean()
# Out:
#           impact_proxy  is_flood_event
# cluster
# 0         29565.463732        0.005649
# 1        132397.950246        0.087835

# %%
# SILHOUETTE SCORES: compare cluster quality for k = 2, 3, 4
# silhouette score near 1 = well-separated clusters; near 0 = overlapping
sil_score = silhouette_score(D_cluster, pred_cluster_labels)
print("Silhoutte Score: k = 3")
print(sil_score)
print()

# compare to other cluster sizes
# Run k-means with k = 2
kmeans2 = KMeans(n_clusters = 2, init = 'k-means++', max_iter = 300, random_state = 0)
pred_cluster_labels2 = kmeans2.fit_predict(D_cluster)
kmeans2.cluster_centers_
sil_score2 = silhouette_score(D_cluster, pred_cluster_labels2)
print("Silhoutte Score: k = 2")
print(sil_score2)
print()

# Run k-means with k = 4
kmeans4 = KMeans(n_clusters = 4, init = 'k-means++', max_iter = 300, random_state = 0)
pred_cluster_labels4 = kmeans4.fit_predict(D_cluster)
kmeans4.cluster_centers_
sil_score4 = silhouette_score(D_cluster, pred_cluster_labels4)
print("Silhoutte Score: k = 4")
print(sil_score4)
print()
# Out:
# Silhoutte Score: k = 3
# 0.5144188859991242
#
# Silhoutte Score: k = 2
# 0.5144188859991242
#
# Silhoutte Score: k = 4
# 0.3533926615465901

# %%
# DBSCAN: density-based clustering as an alternative to K-Means
# useful here because it can find non-spherical clusters and flag outliers as noise (-1)
db = DBSCAN(eps = 0.5, min_samples = 5)
pred_labels = db.fit_predict(D_cluster)

# number of clusters in labels
n_clusters_ = len(set(pred_labels)) - (1 if -1 in pred_labels else 0)
n_noise_ = list(pred_labels).count(-1)

print("Estimated number of clusters: %d" % n_clusters_)
print("Estimated number of noise points: %d" % n_noise_)

plt.scatter(D_cluster[:,0], D_cluster[:,1], c = pred_labels, alpha = 0.5)
plt.title("DBSCAN Clustering on PCA-Transformed Normalized Data")
plt.xlabel("PC1")
plt.ylabel("PC2")
# Out:
# Estimated number of clusters: 4
# Estimated number of noise points: 98
# Text(0, 0.5, 'PC2')

# %%
# profile each cluster by mean feature values in the original (untransformed) space
# this makes the cluster descriptions interpretable in real units
profile_df = D_raw.copy()
profile_df["cluster"] = pred_cluster_labels

cluster_profile = profile_df.groupby("cluster").mean().T
cluster_profile.columns = [f"Cluster {i+1}" for i in cluster_profile.columns]

# sort by cross-cluster variation to highlight the most distinguishing features
cluster_profile["variation"] = cluster_profile.std(axis=1)
cluster_profile = cluster_profile.sort_values("variation", ascending=False)

print("Feature means by cluster (sorted by cross-cluster variation):")
print(cluster_profile.drop(columns="variation").round(3).to_string())
# Out:
# Feature means by cluster (sorted by cross-cluster variation):
#                            Cluster 1  Cluster 2
# storm_min_distance_km      11630.659   7697.606
# api_k_0_90_max                47.912    136.969
# rain_3day_max                 17.641     76.628
# RH2M_max                      81.891     88.692
# duration_above_90              0.031      3.076
# tp_6h_intensity_mm_hr_max      0.925      3.498
# flow_pct_max                   0.513      0.963
# no_storm                       0.746      0.432
# WS2M_max                       2.528      2.789
# area_above_90                  0.000      0.160

# %%
# heatmap of cluster profiles using z-scores so all features are on the same scale
# red = above average, blue = below average relative to global mean
profile_means = profile_df.groupby("cluster").mean()
profile_z = (profile_means - profile_means.mean()) / profile_means.std()
profile_z.index = "Cluster " + profile_z.index.astype(str)

plt.figure(figsize=(14, 4))
sns.heatmap(
    profile_z.T,
    cmap="RdBu_r",
    center=0,
    annot=False,
    linewidths=0.3,
    cbar_kws={"label": "Z-score vs. global mean"}
)
plt.title("Cluster Profiles: Feature Means (Z-scored)")
plt.xlabel("Cluster")
plt.ylabel("Feature")
plt.tight_layout()
plt.savefig("figure_cluster_heatmap.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Trigger Evaluation

# %%
# merge PCA scores and cluster labels back into the full dataset for analysis
analysis_df = df.copy()

analysis_df["PC1"] = pca_transformed_D_scaled[:, 0]
analysis_df["PC2"] = pca_transformed_D_scaled[:, 1]
analysis_df["PC3"] = pca_transformed_D_scaled[:, 2]
analysis_df["cluster"] = pred_cluster_labels

# %%
# define 4 flood triggers
# AND triggers are more conservative (fewer alarms, higher precision)
# OR triggers are more inclusive (more alarms, higher recall)

# Trigger 1: Flow & API (Compound/Balanced)
analysis_df["trigger1"] = ((analysis_df["flow_pct_max"] >= 0.96) & (analysis_df["api_k_0_95_max"].rank(pct=True) >= 0.90)).astype(int)

# Trigger 2: Flow OR API (OR Trigger)
analysis_df["trigger2"] = ((analysis_df["flow_pct_max"] >= 0.975) | (analysis_df["api_k_0_90_max"].rank(pct=True) >= 0.90)).astype(int)

# Trigger 3: Flow AND 3-day Rolling Window Rainfall (Compound/Balanced)
analysis_df["trigger3"] = ((analysis_df["flow_pct_max"] >= 0.96) & (analysis_df["rain_3day_max"].rank(pct=True) >= 0.90)).astype(int)

# Trigger 4: Flow OR 3-day Rolling Window Rainfall (OR Trigger)
analysis_df["trigger4"] = ((analysis_df["flow_pct_max"] >= 0.975) | (analysis_df["rain_3day_max"].rank(pct=True) >= 0.90)).astype(int)

# %%
# label each window as TP/TN/FP/FN for each trigger
trigger_cols = ["trigger1", "trigger2", "trigger3", "trigger4"]

for col in trigger_cols:
    case_col = col + "_case"
    analysis_df[case_col] = "TN"  # default: not triggered, not a flood

    analysis_df.loc[(analysis_df[col] == 1) & (analysis_df["is_flood_event"] == 1), case_col] = "TP"
    analysis_df.loc[(analysis_df[col] == 1) & (analysis_df["is_flood_event"] == 0), case_col] = "FP"
    analysis_df.loc[(analysis_df[col] == 0) & (analysis_df["is_flood_event"] == 1), case_col] = "FN"

analysis_df.head()
# Out:
#   window_id center_date window_start  window_end  window_n_days  \
# 0   W000001  1975-01-04   1975-01-02  1975-01-06              5
# 1   W000002  1975-01-05   1975-01-03  1975-01-07              5
# 2   W000003  1975-01-06   1975-01-04  1975-01-08              5
# 3   W000004  1975-01-07   1975-01-05  1975-01-09              5
# 4   W000005  1975-01-08   1975-01-06  1975-01-10              5
#
#    is_flood_event  n_flood_days_in_window  days_to_nearest_flood_in_window  \
# 0               0                       0                              NaN
# 1               0                       0                              NaN
# 2               0                       0                              NaN
# 3               0                       0                              NaN
# 4               0                       0                              NaN
#
#    flow_raw_max  flow_raw_mean  ...       PC3  cluster  trigger1  trigger2  \
# 0       50.0305       36.84938  ... -0.833882        0         0         0
# 1       45.3183       34.26694  ... -0.799472        0         0         0
# 2       45.3183       37.87166  ... -0.799472        0         0         0
# 3       45.3183       38.02028  ... -0.406916        0         0         0
# 4       42.1990       34.75174  ... -0.324845        0         0         0
#
#    trigger3  trigger4  trigger1_case  trigger2_case  trigger3_case  \
# 0         0         0             TN             TN             TN
# 1         0         0             TN             TN             TN
# 2         0         0             TN             TN             TN
# 3         0         0             TN             TN             TN
# 4         0         0             TN             TN             TN
#
#    trigger4_case
# 0             TN
# 1             TN
# 2             TN
# 3             TN
# 4             TN
#
# [5 rows x 73 columns]

# %%
# compute precision, recall, and F1 for each trigger
# precision = what fraction of alarms are real floods
# recall = what fraction of real floods were caught

summary = []
for col in trigger_cols:
    trigger = analysis_df[col]
    flood = analysis_df["is_flood_event"]

    tp = ((trigger == 1) & (flood == 1)).sum()
    fp = ((trigger == 1) & (flood == 0)).sum()
    fn = ((trigger == 0) & (flood == 1)).sum()
    tn = ((trigger == 0) & (flood == 0)).sum()

    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    f1 = (2 * precision * recall) / (precision + recall)

    summary.append({"trigger": col,
                    "tp": tp, "fp": fp, "fn": fn, "tn": tn,
                    "precision": precision, "recall": recall, "f1": f1})

summary_df = pd.DataFrame(summary)
print(summary_df)
# Out:
#     trigger   tp    fp   fn     tn  precision    recall        f1
# 0  trigger1  197   865  144  17417   0.185499  0.577713  0.280827
# 1  trigger2  247  1779   94  16503   0.121915  0.724340  0.208703
# 2  trigger3  202  1284  139  16998   0.135935  0.592375  0.221128
# 3  trigger4  211  1679  130  16603   0.111640  0.618768  0.189153

# %%
case_col = "trigger1_case"

fn_df = analysis_df[analysis_df[case_col] == "FN"]  # missed floods
fp_df = analysis_df[analysis_df[case_col] == "FP"]  # false alarms
tp_df = analysis_df[analysis_df[case_col] == "TP"]
tn_df = analysis_df[analysis_df[case_col] == "TN"]

# %%
# visualize trigger 1 (Flow AND API) errors in PCA space
# point size = impact severity; helps see if errors cluster around high-impact events
case_col = "trigger1_case"
sizes_impact = (analysis_df["impact_proxy"] / analysis_df["impact_proxy"].max()) * 100

plt.figure()
for case in ["TN", "FP", "FN", "TP"]:
    subset = analysis_df[analysis_df[case_col] == case]
    plt.scatter(subset["PC1"], subset["PC2"], s = sizes_impact[subset.index], alpha = 0.15, label = case)

plt.xlabel("PC1")
plt.ylabel("PC2")
plt.suptitle("Predicted Flow AND API (k = 0.95)")
plt.title("Colored by Confusion Class, Sized by Impact", fontsize = 10)
plt.legend()
plt.grid()
plt.savefig("figure_pca_trig1_comparison.png", dpi = 300, bbox_inches = "tight")
plt.show()

# trigger 2 (Flow OR API)
case_col = "trigger2_case"

for case in ["TN", "FP", "FN", "TP"]:
    subset = analysis_df[analysis_df[case_col] == case]
    plt.scatter(subset["PC1"], subset["PC2"], s = sizes_impact[subset.index], alpha = 0.15, label = case)

plt.xlabel("PC1")
plt.ylabel("PC2")
plt.suptitle("Predicted Flow OR API (k = 0.90)")
plt.title("Colored by Confusion Class, Sized by Impact", fontsize = 10)
plt.legend()
plt.grid()
plt.savefig("figure_pca_trig2_comparison.png", dpi = 300, bbox_inches = "tight")
plt.show()

# %%
# trigger 3 (Flow AND 3-day rain) and trigger 4 (Flow OR 3-day rain)
case_col = "trigger3_case"
sizes_impact = (analysis_df["impact_proxy"] / analysis_df["impact_proxy"].max()) * 100

plt.figure()
for case in ["TN", "FP", "FN", "TP"]:
    subset = analysis_df[analysis_df[case_col] == case]
    plt.scatter(subset["PC1"], subset["PC2"], s = sizes_impact[subset.index], alpha = 0.15, label = case)

plt.xlabel("PC1")
plt.ylabel("PC2")
plt.suptitle("Predicted Flow AND 3Day Rolling Rain")
plt.title("Colored by Confusion Class, Sized by Impact", fontsize = 10)
plt.legend()
plt.grid()
plt.savefig("figure_pca_trig3_comparison.png", dpi = 300, bbox_inches = "tight")
plt.show()

case_col = "trigger4_case"

for case in ["TN", "FP", "FN", "TP"]:
    subset = analysis_df[analysis_df[case_col] == case]
    plt.scatter(subset["PC1"], subset["PC2"], s = sizes_impact[subset.index], alpha = 0.15, label = case)

plt.xlabel("PC1")
plt.ylabel("PC2")
plt.suptitle("Predicted Flow OR 3Day Rolling Rain")
plt.title("Colored by Confusion Class, Sized by Impact", fontsize = 10)
plt.legend()
plt.grid()
plt.savefig("figure_pca_trig4_comparison.png", dpi = 300, bbox_inches = "tight")
plt.show()

# %%
# plot trigger 1 errors (FP and FN) colored by cluster
# triangles = missed floods (FN), X = false alarms (FP)
# reveals whether errors are concentrated in specific weather regimes
case_col = "trigger1_case"
subset = analysis_df[analysis_df[case_col].isin(["FN", "FP"])].copy()

cluster_colors = {0: "blue", 1: "green", 2: "gray"}

for cluster in subset["cluster"].unique():
    data = subset[subset["cluster"] == cluster]
    fn = data[data[case_col] == "FN"]
    fp = data[data[case_col] == "FP"]

    plt.scatter(fn["PC1"], fn["PC2"], c = cluster_colors[cluster], marker = "^",
                alpha = 0.5, label = f"Cluster {cluster + 1} - FN")
    plt.scatter(fp["PC1"], fp["PC2"], c = cluster_colors[cluster], marker = "x",
                alpha = 0.5, label = f"Cluster {cluster + 1} - FP")

plt.xlabel("PC1")
plt.ylabel("PC2")
plt.suptitle("Trigger Errors by Cluster in PCA Flood Feature Space")
plt.title("Predicted Flow AND API (k = 0.95)", fontsize = 10)
plt.grid()
plt.legend()
plt.savefig("figure_pca_clustering_errors.png", dpi = 300, bbox_inches = "tight")
plt.show()

# %%
# proportion of TP/TN/FP/FN within each cluster for trigger 1
# shows whether certain clusters are more error-prone
trigger1_cluster = pd.crosstab(analysis_df["cluster"], analysis_df["trigger1_case"], normalize="index")
print(trigger1_cluster)
# Out:
# trigger1_case        FN        FP        TN        TP
# cluster
# 0              0.005649  0.000000  0.994351  0.000000
# 1              0.019170  0.301499  0.610666  0.068665

# %%
# boxplot of impact distribution
analysis_df.boxplot(column = "impact_proxy", by = "trigger1_case")

plt.suptitle("Impact Distribution by Trigger Outcome")
plt.title("Predicted Flow AND API (k = 0.95)", fontsize = 10)
plt.xlabel("Trigger Outcome")
plt.ylabel("Impact Proxy (m²)")
plt.savefig("figure_trigger1_impact.png", dpi = 300, bbox_inches = "tight") # save as png
plt.show()

# %%
# Which cluster's features explain trigger FNs best?
# Compare FN mean feature profile vs. overall cluster mean
fn_idx = analysis_df[analysis_df["trigger1_case"] == "FN"].index
fn_profile = D_raw.loc[fn_idx].mean()

tp_idx = analysis_df[analysis_df["trigger1_case"] == "TP"].index
tp_profile = D_raw.loc[tp_idx].mean()

comparison = pd.DataFrame({
    "FN": fn_profile,
    "TP": tp_profile,
}).T

# Show top distinguishing features
diff = (comparison.loc["TP"] - comparison.loc["FN"]).abs()
top_diff_cols = diff.sort_values(ascending=False).head(8).index

print("Features where TP and FN differ most:")
print(comparison[top_diff_cols].round(3).to_string())
# Out:
# Features where TP and FN differ most:
#     storm_min_distance_km  api_k_0_90_max  rain_3day_max  RH2M_max  duration_above_90  tp_6h_intensity_mm_hr_max  WS2M_max  no_storm
# FN               9621.576          89.505         37.810    84.372              1.097                      2.220     2.673     0.604
# TP               4163.017         198.842        124.391    91.630              4.310                      4.624     3.352     0.178
